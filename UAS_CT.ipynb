# %%
loop = True


while loop:
    def menu():
        print("---------------")
        print("Selamat Datang di Cinema XXI Taman Anggrek")
        print("Silahkan Pilih Film di Bawah Ini")
        print("   ")
        print("1. Kimetsu no Yaiba")
        print("2. Wonder Woman")
        print("3. Mariposa")
        print("4. Exit")
        print("----------------")


    def pesan():
        jumlah = int(input("Masukkan Jumlah Tiket: "))
        nama = input("Masukkan nama pemesan: ")
        total_harga = jumlah * harga
        print("---------------------------------------------")
        print("Tiket berhasil Dibeli")
        print("Penukaran dapat dilakukan di Cinema XXI Taman Anggrek")
        print("Jumlah tiket yang dibeli: ", jumlah, "tiket")
        print("Atas nama ", nama)
        print("Total Harga ", "Rp.", total_harga)
        print("Terima Kasih atas Pembeliannya")

    menu()
    film = int(input("Masukkan nomor film : "))

    if film == 1:
        print("Harga tiket Rp. 45.000")
        print("Silahkan Pilih Jadwal")
        print("1. Jam  13.30")
        print("2. Jam 16.00")
        print("3. Jam 18.30")
        print("-------------------------------------------------------")
        jadwal = int(input("Masukan nomor pada jadwal : "))

        if jadwal == 1:
            harga = 45000
            print("----------------------------------")
            print("Dipilih jadwal nomor ", int(jadwal))
            print("----------------------------------")
            pesan()

        elif jadwal == 2:
            harga = 45000
            print("----------------------------------")
            print("Dipilih jadwal nomor ", int(jadwal))
            print("----------------------------------")
            pesan()

        elif jadwal == 3:
            harga = 45000
            print("----------------------------------")
            print("Dipilih jadwal nomor ", int(jadwal))
            print("----------------------------------")
            pesan()

        else:
            print("invalid option")

    elif film == 2:
        print("Harga tiket Rp. 35.000")
        print("Silahkan Pilih Jadwal")
        print("1. Jam 15.15")
        print("2. Jam 18.15")
        print("-------------------------------------------------------")
        jadwal = int(input("Masukan nomor pada jadwal : "))

        if jadwal == 1:
            harga = 35000
            print("----------------------------------")
            print("Dipilih jadwal nomor ", int(jadwal))
            print("----------------------------------")
            pesan()

        elif jadwal == 2:
            harga = 35000
            print("----------------------------------")
            print("Dipilih jadwal nomor ", int(jadwal))
            print("----------------------------------")
            pesan()

        else:
            print("invalid option")

    elif film == 3:
        print("Harga tiket Rp. 40.000")
        print("Silahkan Pilih Jadwal")
        print("1. Jam 16.00")
        print("2. Jam 18.00")
        print("-------------------------------------------------------")
        jadwal = int(input("Masukan nomor pada jadwal : "))

        if jadwal == 1:
            harga = 40000
            print("----------------------------------")
            print("Dipilih jadwal nomor ", int(jadwal))
            print("----------------------------------")
            pesan()

        elif jadwal == 2:
            harga = 40000
            print("----------------------------------")
            print("Dipilih jadwal nomor ", int(jadwal))
            print("----------------------------------")
            pesan()

        else:
            print("invalid option")

    elif film == 4:
      print(exit)
      exit()

    else:
        print("Invalid Option")
# Out:
# ---------------
# Selamat Datang di Cinema XXI Taman Anggrek
# Silahkan Pilih Film di Bawah Ini
#
# 1. Kimetsu no Yaiba
# 2. Wonder Woman
# 3. Mariposa
# 4. Exit
# ----------------
# Masukkan nomor film : 4
# ...
# ---------------
# Selamat Datang di Cinema XXI Taman Anggrek
# Silahkan Pilih Film di Bawah Ini
#
# 1. Kimetsu no Yaiba
# 2. Wonder Woman
# 3. Mariposa
# 4. Exit
# ----------------
# Masukkan nomor film : 4
# ...
# ---------------
# Selamat Datang di Cinema XXI Taman Anggrek
# Silahkan Pilih Film di Bawah Ini
#
# 1. Kimetsu no Yaiba
# 2. Wonder Woman
# 3. Mariposa
# 4. Exit
# ----------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-bf1c7c8ffcef> in <module>
#      28
#      29     menu()
# ---> 30     film = int(input("Masukkan nomor film : "))
#      31
#      32     if film == 1:
#
# ...
